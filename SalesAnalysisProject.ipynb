# %% [markdown]
# import librarys

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime 
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# read data

# %%
df = pd.read_csv(r"D:\telegramm\Telegram Desktop\assignment\archive\walmart-sales-dataset-of-45stores.csv")
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %% [markdown]
# describe data

# %%
df.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %% [markdown]
# convert date col to Date object

# %%
df['Date'] = pd.to_datetime(df['Date'])

df.dtypes
# Out:
# Store                       int64
# Date               datetime64[ns]
# Weekly_Sales              float64
# Holiday_Flag                int64
# Temperature               float64
# Fuel_Price                float64
# CPI                       float64
# Unemployment              float64
# Year                        int64
# Month                       int64
# Day                         int64
# MonthYear_value         period[M]
# Holiday                    object
# season                      int64
# season_name                object
# dtype: object

# %% [markdown]
# check if there is null values in data

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %% [markdown]
# drop duplicates in data

# %%
df=df.drop_duplicates()
df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df.loc[comp1[comp1[1]<comp1[0]].index]
# Out:
#        Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# Store
# 30         1 2010-03-09    1540163.53             0        81.21       2.577
# 36         1 2010-10-15    1459409.10             0        67.18       2.720
# 37         1 2010-10-22    1345454.00             0        69.86       2.725
# 38         1 2010-10-29    1384209.22             0        69.64       2.716
# 44         1 2010-10-12    1682614.26             0        46.33       2.843
#
#               CPI  Unemployment  Year  Month  Day MonthYear_value  \
# Store
# 30     211.531248         7.787  2010      3    9         2010-03
# 36     211.813744         7.838  2010     10   15         2010-10
# 37     211.861294         7.838  2010     10   22         2010-10
# 38     211.908844         7.838  2010     10   29         2010-10
# 44     211.465953         7.838  2010     10   12         2010-10
#
#             Holiday  season season_name
# Store
# 30       Super Bowl       2      Spring
# ...

# %%
def assign_holiday(date):
    if date in [ '2010-11-26 00:00:00', '2010-10-09 00:00:00']:
        return 'Super Bowl'
    elif date in [  '2010-12-02 00:00:00', '2011-09-06 00:00:00','2010-12-02 00:00:00']:
        return 'Labour Day'
    elif date in ['2010-11-26 00:00:00', '2011-11-25 00:00:00', '2012-10-23 00:00:00', '2012-11-01 00:00:00']:
        return 'Thanksgiving'
    elif date in ['2010-12-31 00:00:00', '2011-12-30 00:00:00', '2010-12-27 00:00:00']:
        return 'Christmas'
    else:
        return 'Non-Holiday'

# %% [markdown]
# add columns (year, month, day) Date object to data + season column

# %%
df['Year']=df['Date'].dt.year
df['Month']=df['Date'].dt.month
df['Day']=df['Date'].dt.day
df['MonthYear_value'] = df['Date'].dt.to_period('M')
df['Holiday'] = df['Date'].apply(lambda x : assign_holiday(str(x)))
df['season'] = (df['Date'].dt.month%12 + 3)//3
seasons = {
             1: 'Winter',
             2: 'Spring',
             3: 'Summer',
             4: 'Autumn'
}

df['season_name'] = df['season'].map(seasons)
df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
# ...

# %% [markdown]
# Finding the Correlation between Columns using Heatmap

# %%
sns.heatmap(data=df.corr(), annot=True, fmt='.2f', cbar=True)
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                      Store  Weekly_Sales  Holiday_Flag  Temperature  \
# Store         1.000000e+00     -0.335332 -4.386841e-16    -0.022659
# Weekly_Sales -3.353320e-01      1.000000  3.689097e-02    -0.063810
# Holiday_Flag -4.386841e-16      0.036891  1.000000e+00    -0.155091
# Temperature  -2.265908e-02     -0.063810 -1.550913e-01     1.000000
# Fuel_Price    6.002295e-02      0.009464 -7.834652e-02     0.144982
# CPI          -2.094919e-01     -0.072634 -2.162091e-03     0.176888
# Unemployment  2.235313e-01     -0.106176  1.096028e-02     0.101158
# Year          3.474318e-12     -0.018378 -5.678257e-02     0.064269
# Month         6.289676e-16      0.067535  3.322341e-01     0.066440
# Day          -1.070464e-15     -0.014873 -3.603594e-02     0.089019
# season        9.514883e-17     -0.010929  1.197071e-01     0.289900
#
#               Fuel_Price       CPI  Unemployment          Year         Month  \
# ...

# %% [markdown]
# Find corrlation between'Weekly_Sales' and 'Temperature','Fuel_Price','CPI'

# %%
df[['Weekly_Sales','Temperature','Fuel_Price','CPI']].corr()
# Out:
#               Weekly_Sales  Temperature  Fuel_Price       CPI
# Weekly_Sales      1.000000    -0.063810    0.009464 -0.072634
# Temperature      -0.063810     1.000000    0.144982  0.176888
# Fuel_Price        0.009464     0.144982    1.000000 -0.170642
# CPI              -0.072634     0.176888   -0.170642  1.000000

# %% [markdown]
# Value Distribution

# %%
df[['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature','Fuel_Price', 'CPI', 'Unemployment']].plot(subplots=True,  figsize=(15,15))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %% [markdown]
# visualize quantitive variables

# %%
for column in [ 'Date', 'Weekly_Sales', 'Temperature','Fuel_Price', 'CPI', 'Unemployment', 'Year', 'Month', 'Day']:
    plt.figure()             
    sns.distplot(df[column])

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.barplot(data=df, x="Store", y="Weekly_Sales", hue="Holiday_Flag", ax=ax)
# Out:
# <AxesSubplot:xlabel='Store', ylabel='Weekly_Sales'>

# %%
df[['Year', 'Holiday_Flag','Temperature','CPI','Fuel_Price', 'Unemployment']].hist(bins=15, figsize=(16, 6))
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'Holiday_Flag'}>],
#        [<AxesSubplot:title={'center':'Temperature'}>,
#         <AxesSubplot:title={'center':'CPI'}>],
#        [<AxesSubplot:title={'center':'Fuel_Price'}>,
#         <AxesSubplot:title={'center':'Unemployment'}>]], dtype=object)

# %%
sales_year = df.groupby(['MonthYear_value']).sum()
sales_year[['Weekly_Sales']].plot(figsize=(16, 6), subplots=True)
# Out:
# array([<AxesSubplot:xlabel='MonthYear_value'>], dtype=object)

# %% [markdown]
# we find Weekly_Sales good in May and Dec

# %%
plt.figure(figsize=(14,7), dpi=80)
plt.bar(df['Month'], df['Weekly_Sales'])
plt.xlabel('Months')
plt.ylabel('Weekly_Sales')
plt.title('Monthwise Sales')
# Out:
# Text(0.5, 1.0, 'Monthwise Sales')

# %% [markdown]
# we find Weekly_Sales is best in Dec

# %%
plt.figure(figsize=(14,7), dpi=80)
plt.bar(df['season_name'], df['Weekly_Sales'])
plt.xlabel('season_name')
plt.ylabel('Weekly_Sales')
plt.title('Monthwise Sales')
# Out:
# Text(0.5, 1.0, 'Monthwise Sales')

# %% [markdown]
# we Find Sales in Winter is better

# %%
plt.figure(figsize=(10,7), dpi=80)
df.groupby('Year')[['Weekly_Sales']].sum().plot(kind='bar', legend=False)
plt.title('Yearly Sales')
# Out:
# Text(0.5, 1.0, 'Yearly Sales')

# %%
fig, axis = plt.subplots(4, figsize=(12,16))
x = df[['Temperature','Fuel_Price','CPI','Unemployment']]

for i, column in enumerate(x):
    sns.boxplot(df[column], ax=axis[i])

# %% [markdown]
# Group by data frame by Store

# %%
groupby_of_data1 = df.groupby(["Store"])['Weekly_Sales'].sum().to_frame()
groupby_of_data1.head()
# Out:
#        Weekly_Sales
# Store
# 1      2.224028e+08
# 2      2.753824e+08
# 3      5.758674e+07
# 4      2.995440e+08
# 5      4.547569e+07

# %%
groupby_of_data1[groupby_of_data1['Weekly_Sales']==groupby_of_data1['Weekly_Sales'].max()]
# Out:
#        Weekly_Sales
# Store
# 20     3.013978e+08

# %% [markdown]
# Which store has maximum sales?
#
# store 20

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.barplot(data=groupby_of_data1, x=groupby_of_data1.index, y="Weekly_Sales", ax=ax)
# Out:
# <AxesSubplot:xlabel='Store', ylabel='Weekly_Sales'>

# %%
Pivot_of_data=pd.pivot_table(data=df,index=["Store"], values= 'Weekly_Sales',aggfunc=np.std)
Pivot_of_data.head()
# Out:
#         Weekly_Sales
# Store
# 1      155980.767761
# 2      237683.694682
# 3       46319.631557
# 4      266201.442297
# 5       37737.965745

# %%
Pivot_of_data[Pivot_of_data['Weekly_Sales']==Pivot_of_data['Weekly_Sales'].max()]
# Out:
#         Weekly_Sales
# Store
# 14     317569.949476

# %% [markdown]
# Which store has maximum standard deviation i.e., the sales vary a lot?
#
#
# store   14

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.barplot(data=Pivot_of_data, x=Pivot_of_data.index, y="Weekly_Sales", ax=ax)
# Out:
# <AxesSubplot:xlabel='Store', ylabel='Weekly_Sales'>

# %%
#comp1=df.pivot_table(index=['Store'],columns=['Holiday_Flag'] ,values='Weekly_Sales',aggfunc={'Weekly_Sales': lambda x:x.mean() })
#comp1

# %% [markdown]
# Some holidays have a negative impact on sales  holidays
# that have higher sales than the mean sales in the non-holiday season
# for all stores together.

# %%
mm=pd.DataFrame(index=df.Store,data=df[['Date','Weekly_Sales','Fuel_Price','Holiday_Flag','Holiday']])
mm.head()
# Out:
#             Date  Weekly_Sales  Fuel_Price  Holiday_Flag     Holiday
# Store
# 1     2010-12-02    1641957.44       2.548             1  Labour Day
# 1     2010-12-02    1641957.44       2.548             1  Labour Day
# 1     2010-12-02    1641957.44       2.548             1  Labour Day
# 1     2010-12-02    1641957.44       2.548             1  Labour Day
# 1     2010-12-02    1641957.44       2.548             1  Labour Day

# %%
nono=mm[(mm['Holiday_Flag']==1)>(mm['Holiday_Flag']==0)]
nono['Holiday'].unique()
# Out:
# array(['Labour Day', 'Super Bowl'], dtype=object)

# %%
df.iloc[nono.index]
# Out:
#     Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1       1 2010-12-02    1641957.44             1        38.51       2.548
# 1       1 2010-12-02    1641957.44             1        38.51       2.548
# 1       1 2010-12-02    1641957.44             1        38.51       2.548
# 1       1 2010-12-02    1641957.44             1        38.51       2.548
# 1       1 2010-12-02    1641957.44             1        38.51       2.548
# ..    ...        ...           ...           ...          ...         ...
# 42      1 2010-11-26    1955624.11             1        64.52       2.735
# 42      1 2010-11-26    1955624.11             1        64.52       2.735
# 42      1 2010-11-26    1955624.11             1        64.52       2.735
# 42      1 2010-11-26    1955624.11             1        64.52       2.735
# 42      1 2010-11-26    1955624.11             1        64.52       2.735
#
#            CPI  Unemployment  Year  Month  Day MonthYear_value     Holiday  \
# ...

# %%
nono.index.unique()
# Out:
# Int64Index([1, 31, 42], dtype='int64', name='Store')

# %% [markdown]
# holidays have a negative impact on sales are 3  Stores store:[1,31,42] in ['Labour Day', 'Super Bowl'] Holidays

# %% [markdown]
# Provide a semester view of sales in units

# %%
dd=df.groupby(["season_name"])['Weekly_Sales'].sum().to_frame()
dd
# Out:
#              Weekly_Sales
# season_name
# Autumn       1.652620e+09
# Spring       1.804507e+09
# Summer       1.732564e+09
# Winter       1.547528e+09

# %%
label=['Autumn','Spring','Summer','Winter']
explode = [0.04, 0.03, 0.03, 0.04]
plt.pie(dd['Weekly_Sales'],labels=label,explode=explode,  autopct='%.0f%%')
plt.show()

# %% [markdown]
# Provide a monthly view of sales in units

# %%
dm=df.groupby(["Month"])['Weekly_Sales'].sum().to_frame()
dm
# Out:
#        Weekly_Sales
# Month
# 1      4.264263e+08
# 2      5.220257e+08
# 3      5.534864e+08
# 4      6.453239e+08
# 5      6.056966e+08
# 6      5.750180e+08
# 7      5.933139e+08
# 8      5.642317e+08
# 9      5.905323e+08
# 10     6.029189e+08
# 11     4.591693e+08
# 12     5.990761e+08

# %%
abel=range(1,13 )
explode = [0.04, 0.03, 0.03, 0.04]
plt.pie(dm['Weekly_Sales'],labels=abel,  autopct='%.0f%%')
plt.show()

# %% [markdown]
# RFM

# %%
now = datetime(2022,12,25)

# %%
rfm = mm.groupby('Store').agg({'Date': lambda x : (now-x.max()).days  ,                  
                               'Fuel_Price' :lambda Fuel_Price :Fuel_Price.sum(),
                               'Weekly_Sales':lambda Weekly_Sales :Weekly_Sales.sum() 
                              }
                               
                               )
rfm.head()
# Out:
#        Date  Fuel_Price  Weekly_Sales
# Store
# 1      4406     364.364  2.347999e+08
# 2      4692     359.502  2.305114e+08
# 3      4685     366.223  2.015910e+08
# 4      4619     375.375  2.223374e+08
# 5      4405     381.381  2.058544e+08

# %%
col_list=['Recency','Frequency','Monetary']
rfm.columns=col_list
rfm.head()
# Out:
#        Recency  Frequency      Monetary
# Store
# 1         4406    364.364  2.347999e+08
# 2         4692    359.502  2.305114e+08
# 3         4685    366.223  2.015910e+08
# 4         4619    375.375  2.223374e+08
# 5         4405    381.381  2.058544e+08

# %%
rfm["R"]=pd.qcut(rfm['Recency'],5,labels=[5,4,3,2,1])
rfm["F"]=pd.qcut(rfm['Frequency'],5,labels=[5,4,3,2,1])
rfm["M"]=pd.qcut(rfm['Monetary'],5,labels=[1,2,3,4,5])
rfm["RFM_Score"]=rfm["R"].astype(str)+rfm["F"].astype(str)+rfm["M"].astype(str)
rfm.head()
# Out:
#        Recency  Frequency      Monetary  R  F  M RFM_Score
# Store
# 1         4406    364.364  2.347999e+08  5  5  5       555
# 2         4692    359.502  2.305114e+08  1  5  5       155
# 3         4685    366.223  2.015910e+08  1  5  1       151
# 4         4619    375.375  2.223374e+08  2  4  4       244
# 5         4405    381.381  2.058544e+08  5  3  2       532

# %%
seg_map = {
 r'[1-2][1-2]': 'Hibernating',
 r'[1-2][3-4]': 'At Risk',
 r'[1-2]5': 'Can\'t Loose',
 r'3[1-2]': 'About to Sleep',
 r'33': 'Need Attention',
 r'[3-4][4-5]': 'Loyal Customers',
 r'41': 'Promising',
 r'51': 'New Customers',
 r'[4-5][2-3]': 'Potential Loyalists',
 r'5[4-5]': 'Champions'
}

# %%
rfm['Segment']=rfm['M'].astype(str)+rfm['F'].astype(str)
rfm['Segment']=rfm['Segment'].replace(seg_map,regex=True)
rfm.head()
# Out:
#        Recency  Frequency      Monetary  R  F  M RFM_Score          Segment
# Store
# 1         4406    364.364  2.347999e+08  5  5  5       555        Champions
# 2         4692    359.502  2.305114e+08  1  5  5       155        Champions
# 3         4685    366.223  2.015910e+08  1  5  1       151      Can't Loose
# 4         4619    375.375  2.223374e+08  2  4  4       244  Loyal Customers
# 5         4405    381.381  2.058544e+08  5  3  2       532          At Risk

# %% [markdown]
# Plot the relations between weekly sales vs. other numeric features
